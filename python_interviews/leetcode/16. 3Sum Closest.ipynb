# %% [raw]
# Given an integer array nums of length n and an integer target, find three integers in nums such that the sum is closest to target.
#
# Return the sum of the three integers.
#
# You may assume that each input would have exactly one solution.
#
#
#
# Example 1:
#
# Input: nums = [-1,2,1,-4], target = 1
# Output: 2
# Explanation: The sum that is closest to the target is 2. (-1 + 2 + 1 = 2).
# Example 2:
#
# Input: nums = [0,0,0], target = 1
# Output: 0
# Explanation: The sum that is closest to the target is 0. (0 + 0 + 0 = 0).
#
#
# Constraints:
#
# 3 <= nums.length <= 500
# -1000 <= nums[i] <= 1000
# -104 <= target <= 104

# %%
class Solution(object):
    def threeSumClosest(self, nums, target):
        semiresult = {}
        result = []
        nums.sort()
        currentdiff = None
        closestno = None
        print(nums)
        for index,value in enumerate(nums):
            print(f"===================={index+1} loop =================")
            if index > 0 and value == nums[index-1]:
                continue
            left = index +1
            right =  len(nums) -1
            print(f"left => {left}")
            print(f"right => {right}")
            while left < right:
                print("-----------")
                tsum = value + nums[left]+ nums[right]
                print(f"left => {left}")
                print(f"right => {right}")
                if currentdiff is None and closestno is None:
                    print(f"{value} + {nums[left]}+ {nums[right]}")
                    currentdiff = target - tsum
                    closestno = tsum
                if abs(currentdiff) < abs(closestno):
                    print(f"{value} + {nums[left]}+ {nums[right]}")
                    closestno = currentdiff
                if currentdiff < 0:
                    right-=1
                elif currentdiff > 0:
                    left+=1
                else:
                    print(f"{value} + {nums[left]}+ {nums[right]}")
                    return closestno

        return closestno

# %%
obj1 = Solution()
print(obj1.threeSumClosest([4,0,5,-5,3,3,0,-4,-5],-2))
# Out:
# [-5, -5, -4, 0, 0, 3, 3, 4, 5]
# ====================1 loop =================
# left => 1
# right => 8
# -----------
# left => 1
# right => 8
# -5 + -5+ 5
# -5 + -5+ 5
# -----------
# left => 2
# right => 8
# -----------
# left => 3
# right => 8
# -----------
# left => 4
# right => 8
# -----------
# left => 5
# right => 8
# -----------
# left => 6
# right => 8
# -----------
# left => 7
# right => 8
# ====================2 loop =================
# ====================3 loop =================
# left => 3
# right => 8
# -----------
# left => 3
# right => 8
# -----------
# left => 4
# right => 8
# -----------
# left => 5
# right => 8
# -----------
# left => 6
# right => 8
# -----------
# left => 7
# right => 8
# ====================4 loop =================
# left => 4
# right => 8
# -----------
# left => 4
# right => 8
# -----------
# left => 5
# right => 8
# -----------
# left => 6
# right => 8
# -----------
# left => 7
# right => 8
# ====================5 loop =================
# ...

# %%
abs(0)
# Out:
# 0

# %%
lst = [-5, -5, -4, 0, 0, 3, 3, 4, 5]
for i in range(len(lst)):
    for j in range(1,len(lst)-1):
        for k in range(2,len(lst)-2):
            if lst[i]+lst[j]+lst[k] == -2:
                print(lst[i],lst[j],lst[k])
# Out:
# -5 0 3
# -5 0 3
# -5 0 3
# -5 0 3
# -5 3 0
# -5 3 0
# -5 3 0
# -5 3 0
# -5 0 3
# -5 0 3
# -5 0 3
# -5 0 3
# -5 3 0
# -5 3 0
# -5 3 0
# -5 3 0
# 0 -5 3
# 0 -5 3
# 0 -5 3
# 0 -5 3
# 3 -5 0
# 3 -5 0
# 3 -5 0
# 3 -5 0

# %%
# old version
class Solution(object):
    def threeSumClosest(self, nums, target):
        semiresult = {}
        result = []
        nums.sort()
        for index,value in enumerate(nums):
            if index > 0 and value == nums[index-1]:
                continue
            left = index +1
            right =  len(nums) -1
            while left < right:
                tsum = value + nums[left]+ nums[right]
                if abs(target-tsum) not in semiresult.keys():
                    semiresult[abs(target-tsum)] = []
                    semiresult[abs(target-tsum)].append([value,nums[left],nums[right]])
                else:
                    semiresult[abs(target-tsum)].append([value,nums[left],nums[right]])
                left+=1
                while nums[left] == nums[left-1] and left < right:
                    left+=1
        result = list(semiresult.keys())
        result.sort()
        return semiresult[result[0]][0][0]+semiresult[result[0]][0][1]+semiresult[result[0]][0][2]
