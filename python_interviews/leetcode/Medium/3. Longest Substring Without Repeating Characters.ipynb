# %%
'''
Given a string s, find the length of the longest substring without duplicate characters.

 

Example 1:

Input: s = "abcabcbb"
Output: 3
Explanation: The answer is "abc", with the length of 3.
Example 2:

Input: s = "bbbbb"
Output: 1
Explanation: The answer is "b", with the length of 1.
Example 3:

Input: s = "pwwkew"
Output: 3
Explanation: The answer is "wke", with the length of 3.
Notice that the answer must be a substring, "pwke" is a subsequence and not a substring.
 

Constraints:

0 <= s.length <= 5 * 104
s consists of English letters, digits, symbols and spaces.
'''

# %%
class Solution:
    def lengthOfLongestSubstring(self, s: str) -> int:
        max_word = []
        max_length = 0
        for i in s:
            if i not in max_word:
                max_word.append(i)
            else:
                print(max_word)
                max_length = len(max_word) if len(max_word) > max_length else max_length
                max_word = []
                max_word.append(i)
                
        max_length = len(max_word) if len(max_word) > max_length else max_length
        return max_length

# %%
s = "abcabcbb"

obj = Solution()
obj.lengthOfLongestSubstring(s)
# Out:
# 3

# %%
s = "bbbbb"

obj = Solution()
obj.lengthOfLongestSubstring(s)
# Out:
# 1

# %%
s = "pwwkew"

obj = Solution()
obj.lengthOfLongestSubstring(s)
# Out:
# 3

# %%
s = "aab"

obj = Solution()
obj.lengthOfLongestSubstring(s)
# Out:
# 2

# %%
s = "dvdf"

obj = Solution()
obj.lengthOfLongestSubstring(s)
## Answer should have been 3
# Out:
# ['d', 'v']
# 2
